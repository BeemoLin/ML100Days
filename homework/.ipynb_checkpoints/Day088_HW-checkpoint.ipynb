# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units,
                                  activation="relu",
                                  name="hidden_layer" + str(i + 1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units,
                                  activation="relu",
                                  name="hidden_layer" + str(i + 1))(x)
            x = BatchNormalization()(x)
            
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

"""
confusion_matrix
# y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
# y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
# tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"]).ravel()

# or
# tp = sum(y_true*y_pred)
# tn = sum((y_true==0) & (y_pred==0))
"""

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_tp"] = sum(y_true*y_pred)
        logs["val_tn"] = sum((y_true==0) & (y_pred==0))
        
rec_tptn = Record_tp_tn()

# %%
"""
# 載入 Callbacks，撰寫一個 f1 score 的 callback function
"""

from keras.callbacks import Callback
from sklearn.metrics import f1_score

class f1sc(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")
        
log_f1sc = f1sc()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train,
         epochs=EPOCHS,
         batch_size=BATCH_SIZE,
         validation_data=(x_test, y_test),
         shuffle=True,
         callbacks=[log_f1sc, rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

# 在訓練後，將 f1sc 紀錄調出
valid_f1sc = model.history.history['val_f1sc']

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""

valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 5s 100us/step - loss: 2.2598 - accuracy: 0.2620 - val_loss: 2.1413 - val_accuracy: 0.2053
# /Users/beemolin/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Epoch 2/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.7648 - accuracy: 0.3845 - val_loss: 1.9899 - val_accuracy: 0.3001
# Epoch 3/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.6412 - accuracy: 0.4256 - val_loss: 1.8312 - val_accuracy: 0.3800
# Epoch 4/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.5691 - accuracy: 0.4509 - val_loss: 1.7237 - val_accuracy: 0.4110
# Epoch 5/25
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.5137 - accuracy: 0.4720 - val_loss: 1.6432 - val_accuracy: 0.4338
# Epoch 6/25
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.4702 - accuracy: 0.4876 - val_loss: 1.5860 - val_accuracy: 0.4426
# Epoch 7/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.4305 - accuracy: 0.5016 - val_loss: 1.5537 - val_accuracy: 0.4532
# Epoch 8/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.3976 - accuracy: 0.5137 - val_loss: 1.5359 - val_accuracy: 0.4564
# Epoch 9/25
# 50000/50000 [==============================] - 4s 84us/step - loss: 1.3656 - accuracy: 0.5258 - val_loss: 1.5201 - val_accuracy: 0.4606
# Epoch 10/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.3375 - accuracy: 0.5350 - val_loss: 1.5089 - val_accuracy: 0.4655
# Epoch 11/25
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.3130 - accuracy: 0.5455 - val_loss: 1.5122 - val_accuracy: 0.4686
# Epoch 12/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.2891 - accuracy: 0.5540 - val_loss: 1.4988 - val_accuracy: 0.4746
# Epoch 13/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.2663 - accuracy: 0.5626 - val_loss: 1.4908 - val_accuracy: 0.4733
# Epoch 14/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.2440 - accuracy: 0.5701 - val_loss: 1.4888 - val_accuracy: 0.4805
# Epoch 15/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.2239 - accuracy: 0.5783 - val_loss: 1.4911 - val_accuracy: 0.4761
# Epoch 16/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.2051 - accuracy: 0.5860 - val_loss: 1.4705 - val_accuracy: 0.4858
# Epoch 17/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.1840 - accuracy: 0.5918 - val_loss: 1.4649 - val_accuracy: 0.4835
# Epoch 18/25
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.1655 - accuracy: 0.6001 - val_loss: 1.4704 - val_accuracy: 0.4837
# Epoch 19/25
# 50000/50000 [==============================] - 4s 87us/step - loss: 1.1478 - accuracy: 0.6083 - val_loss: 1.4659 - val_accuracy: 0.4865
# Epoch 20/25
# 50000/50000 [==============================] - 4s 86us/step - loss: 1.1282 - accuracy: 0.6142 - val_loss: 1.4642 - val_accuracy: 0.4885
# Epoch 21/25
# 50000/50000 [==============================] - 4s 85us/step - loss: 1.1121 - accuracy: 0.6201 - val_loss: 1.4607 - val_accuracy: 0.4842
# Epoch 22/25
# 50000/50000 [==============================] - 5s 93us/step - loss: 1.0947 - accuracy: 0.6255 - val_loss: 1.4563 - val_accuracy: 0.4906
# Epoch 23/25
# 50000/50000 [==============================] - 4s 88us/step - loss: 1.0769 - accuracy: 0.6324 - val_loss: 1.4755 - val_accuracy: 0.4869
# Epoch 24/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.0613 - accuracy: 0.6405 - val_loss: 1.4652 - val_accuracy: 0.4884
# Epoch 25/25
# 50000/50000 [==============================] - 4s 89us/step - loss: 1.0442 - accuracy: 0.6453 - val_loss: 1.4615 - val_accuracy: 0.4948

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_f1sc)), valid_f1sc, label="valid f1-score")
plt.legend()
plt.title("F1-score")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
