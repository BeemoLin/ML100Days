# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
"""
# 載入 Callbacks, 並將監控目標設為 validation loss, 且只存最佳參數時的模型
"""
# 試比較 save_best_only 與否的差異
# 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test
from keras.callbacks import ModelCheckpoint

# model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
#                              monitor="val_loss", 
#                              save_best_only=True,
#                              mode="max")
model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss",
                             save_best_only=True,
                             save_weights_only=True)

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

print('test before save: ', model.predict(x_test))

del model # deletes the existing model
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 7s 147us/step - loss: 2.2198 - accuracy: 0.2691 - val_loss: 2.1594 - val_accuracy: 0.1943
# Epoch 2/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.7465 - accuracy: 0.3886 - val_loss: 1.9822 - val_accuracy: 0.2826
# Epoch 3/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.6225 - accuracy: 0.4310 - val_loss: 1.8240 - val_accuracy: 0.3652
# Epoch 4/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.5485 - accuracy: 0.4576 - val_loss: 1.7089 - val_accuracy: 0.4058
# Epoch 5/50
# 50000/50000 [==============================] - 7s 138us/step - loss: 1.4933 - accuracy: 0.4777 - val_loss: 1.6376 - val_accuracy: 0.4263
# Epoch 6/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 1.4493 - accuracy: 0.4936 - val_loss: 1.5843 - val_accuracy: 0.4450
# Epoch 7/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.4085 - accuracy: 0.5082 - val_loss: 1.5656 - val_accuracy: 0.4396
# Epoch 8/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.3720 - accuracy: 0.5222 - val_loss: 1.5272 - val_accuracy: 0.4577
# Epoch 9/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.3402 - accuracy: 0.5335 - val_loss: 1.5162 - val_accuracy: 0.4608
# Epoch 10/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.3088 - accuracy: 0.5451 - val_loss: 1.4970 - val_accuracy: 0.4689
# Epoch 11/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.2791 - accuracy: 0.5547 - val_loss: 1.4876 - val_accuracy: 0.4717
# Epoch 12/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.2525 - accuracy: 0.5658 - val_loss: 1.4792 - val_accuracy: 0.4737
# Epoch 13/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 1.2251 - accuracy: 0.5759 - val_loss: 1.4760 - val_accuracy: 0.4805
# Epoch 14/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.2014 - accuracy: 0.5846 - val_loss: 1.4704 - val_accuracy: 0.4756
# Epoch 15/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.1740 - accuracy: 0.5953 - val_loss: 1.4680 - val_accuracy: 0.4797
# Epoch 16/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.1508 - accuracy: 0.6050 - val_loss: 1.4639 - val_accuracy: 0.4836
# Epoch 17/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.1292 - accuracy: 0.6130 - val_loss: 1.4729 - val_accuracy: 0.4806
# Epoch 18/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.1045 - accuracy: 0.6221 - val_loss: 1.4577 - val_accuracy: 0.4863
# Epoch 19/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.0834 - accuracy: 0.6302 - val_loss: 1.4723 - val_accuracy: 0.4842
# Epoch 20/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 1.0612 - accuracy: 0.6383 - val_loss: 1.4647 - val_accuracy: 0.4851
# Epoch 21/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.0385 - accuracy: 0.6467 - val_loss: 1.4666 - val_accuracy: 0.4896
# Epoch 22/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 1.0176 - accuracy: 0.6558 - val_loss: 1.4532 - val_accuracy: 0.4958
# Epoch 23/50
# 50000/50000 [==============================] - 6s 128us/step - loss: 0.9966 - accuracy: 0.6626 - val_loss: 1.4545 - val_accuracy: 0.4978
# Epoch 24/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.9739 - accuracy: 0.6729 - val_loss: 1.4696 - val_accuracy: 0.4869
# Epoch 25/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.9524 - accuracy: 0.6793 - val_loss: 1.4621 - val_accuracy: 0.4957
# Epoch 26/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.9319 - accuracy: 0.6864 - val_loss: 1.4714 - val_accuracy: 0.4937
# Epoch 27/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.9133 - accuracy: 0.6959 - val_loss: 1.4769 - val_accuracy: 0.4948
# Epoch 28/50
# 50000/50000 [==============================] - 6s 127us/step - loss: 0.8925 - accuracy: 0.7045 - val_loss: 1.4692 - val_accuracy: 0.4975
# Epoch 29/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.8702 - accuracy: 0.7139 - val_loss: 1.4823 - val_accuracy: 0.4949
# Epoch 30/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.8534 - accuracy: 0.7192 - val_loss: 1.4934 - val_accuracy: 0.4938
# Epoch 31/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.8307 - accuracy: 0.7290 - val_loss: 1.4961 - val_accuracy: 0.4940
# Epoch 32/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.8112 - accuracy: 0.7363 - val_loss: 1.5020 - val_accuracy: 0.4910
# Epoch 33/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.7932 - accuracy: 0.7438 - val_loss: 1.4991 - val_accuracy: 0.4934
# Epoch 34/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.7733 - accuracy: 0.7522 - val_loss: 1.5179 - val_accuracy: 0.4949
# Epoch 35/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.7540 - accuracy: 0.7593 - val_loss: 1.5052 - val_accuracy: 0.4991
# Epoch 36/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.7337 - accuracy: 0.7691 - val_loss: 1.5131 - val_accuracy: 0.4933
# Epoch 37/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.7132 - accuracy: 0.7757 - val_loss: 1.5479 - val_accuracy: 0.4904
# Epoch 38/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.6963 - accuracy: 0.7813 - val_loss: 1.5563 - val_accuracy: 0.4906
# Epoch 39/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.6788 - accuracy: 0.7897 - val_loss: 1.5581 - val_accuracy: 0.4949
# Epoch 40/50
# 50000/50000 [==============================] - 6s 125us/step - loss: 0.6583 - accuracy: 0.7970 - val_loss: 1.5740 - val_accuracy: 0.4917
# Epoch 41/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.6416 - accuracy: 0.8027 - val_loss: 1.5741 - val_accuracy: 0.4979
# Epoch 42/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.6212 - accuracy: 0.8101 - val_loss: 1.6047 - val_accuracy: 0.4883
# Epoch 43/50
# 50000/50000 [==============================] - 7s 141us/step - loss: 0.6061 - accuracy: 0.8179 - val_loss: 1.5984 - val_accuracy: 0.4939
# Epoch 44/50
# 50000/50000 [==============================] - 7s 130us/step - loss: 0.5882 - accuracy: 0.8224 - val_loss: 1.6299 - val_accuracy: 0.4870
# Epoch 45/50
# 50000/50000 [==============================] - 6s 126us/step - loss: 0.5700 - accuracy: 0.8328 - val_loss: 1.6025 - val_accuracy: 0.4974
# Epoch 46/50
# 50000/50000 [==============================] - 6s 124us/step - loss: 0.5535 - accuracy: 0.8393 - val_loss: 1.6336 - val_accuracy: 0.4901
# Epoch 47/50
# 50000/50000 [==============================] - 6s 122us/step - loss: 0.5360 - accuracy: 0.8467 - val_loss: 1.6536 - val_accuracy: 0.4971
# Epoch 48/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.5185 - accuracy: 0.8513 - val_loss: 1.6869 - val_accuracy: 0.4799
# Epoch 49/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.5030 - accuracy: 0.8574 - val_loss: 1.6749 - val_accuracy: 0.4936
# Epoch 50/50
# 50000/50000 [==============================] - 6s 123us/step - loss: 0.4864 - accuracy: 0.8641 - val_loss: 1.6900 - val_accuracy: 0.4889
# test before save:  [[6.1575056e-04 3.3712830e-02 4.6059021e-01 ... 3.9877393e-04
#   1.1897382e-01 9.8406512e-04]
#  [4.5349267e-03 1.7562728e-02 1.5779705e-04 ... 1.6404581e-05
#   9.0319484e-01 7.3731132e-02]
#  [1.4686207e-01 1.4845545e-02 3.6411497e-03 ... 4.9007824e-03
#   8.1422865e-01 1.2371618e-02]
#  ...
#  [2.5039076e-04 3.1854401e-04 3.1060922e-01 ... 2.3189120e-03
#   1.5909463e-02 3.6566277e-04]
#  [3.2543674e-02 2.4263419e-02 2.7241433e-01 ... 2.3186419e-02
#   2.6878141e-02 3.2641250e-01]
#  [1.2322201e-03 1.9906131e-04 7.2890259e-02 ... 7.4409258e-01
#   9.5546786e-03 5.7717152e-03]]

# %%
# Load back
# 导入保存好的模型，再执行一遍预测
# model = keras.models.load_model("./tmp.h5")

# loss_loadback, acc_loadback = model.evaluate(x_test, y_test)


# ValueError: Cannot create group in read-only mode.

# load weights
model_load = build_mlp(input_shape=x_train.shape[1:])
model_load.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model_load.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)


model_load.load_weights("./tmp.h5")

# saved model loss & acc
loss_loadback, acc_loadback = model_load.evaluate(x_test, y_test)


print('test before save: ', model_load.predict(x_test))

print("loss_loadback:", loss_loadback)
print("acc_loadback:", acc_loadback)
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# 10000/10000 [==============================] - 2s 174us/step
# test before save:  [[1.2110245e-02 1.5037514e-01 1.8650235e-01 ... 1.4646042e-03
#   2.1083131e-01 4.8343455e-03]
#  [1.6699987e-02 3.9253685e-01 4.5517288e-04 ... 3.1427600e-05
#   3.6719462e-01 2.1853393e-01]
#  [7.9828843e-02 4.6468388e-02 3.0030892e-03 ... 2.4952639e-03
#   8.3216453e-01 3.0853078e-02]
#  ...
#  [1.8179136e-03 3.5746046e-03 2.4805294e-01 ... 8.4415218e-03
#   6.4841047e-02 3.5145823e-03]
#  [5.4207742e-02 5.2433193e-02 2.4948236e-01 ... 4.3383613e-02
#   2.1213859e-02 1.2384735e-01]
#  [3.6936782e-02 1.3509254e-03 1.4651676e-01 ... 3.2450289e-01
#   5.1523954e-02 4.1651491e-02]]
# loss_loadback: 1.4532297065734863
# acc_loadback: 0.4957999885082245

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
